# %%
import json
import numpy as np
from time import sleep
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
coin_tickers = cg.get_coin_ticker_by_id(id='bitcoin', target='USD')

# %%
coin_tickers
# Out:
# {'name': 'Bitcoin',
#  'tickers': [{'base': 'BTC',
#    'target': 'USDT',
#    'market': {'name': 'Binance',
#     'identifier': 'binance',
#     'has_trading_incentive': False},
#    'last': 52123.05,
#    'volume': 99474.30804781469,
#    'converted_last': {'btc': 1.000049, 'eth': 32.47203, 'usd': 52180},
#    'converted_volume': {'btc': 99479, 'eth': 3230133, 'usd': 5190567869},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.010019,
#    'timestamp': '2021-03-25T20:40:47+00:00',
#    'last_traded_at': '2021-03-25T20:40:47+00:00',
#    'last_fetch_at': '2021-03-25T20:40:47+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://www.binance.com/en/trade/BTC_USDT',
#    'token_info_url': None,
#    'coin_id': 'bitcoin',
#    'target_coin_id': 'tether'},
#   {'base': 'BTC',
#    'target': 'GBP',
#    'market': {'name': 'Bitfinex',
#     'identifier': 'bitfinex',
#     'has_trading_incentive': False},
#    'last': 37958.0,
# ...

# %%
btc = coin_tickers['tickers']

# %%
btc
# Out:
# [{'base': 'BTC',
#   'target': 'USDT',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 52123.05,
#   'volume': 99474.30804781469,
#   'converted_last': {'btc': 1.000049, 'eth': 32.47203, 'usd': 52180},
#   'converted_volume': {'btc': 99479, 'eth': 3230133, 'usd': 5190567869},
#   'trust_score': 'green',
#   'bid_ask_spread_percentage': 0.010019,
#   'timestamp': '2021-03-25T20:40:47+00:00',
#   'last_traded_at': '2021-03-25T20:40:47+00:00',
#   'last_fetch_at': '2021-03-25T20:40:47+00:00',
#   'is_anomaly': False,
#   'is_stale': False,
#   'trade_url': 'https://www.binance.com/en/trade/BTC_USDT',
#   'token_info_url': None,
#   'coin_id': 'bitcoin',
#   'target_coin_id': 'tether'},
#  {'base': 'BTC',
#   'target': 'USD',
#   'market': {'name': 'Bitfinex',
#    'identifier': 'bitfinex',
#    'has_trading_incentive': False},
#   'last': 52092.0,
#   'volume': 16423.3290811,
# ...

# %%
processed = []
starting_price = 19451.45
while True:
    for exchange in btc:
        if exchange['target'] == 'USDT' or exchange['target'] == 'USD' and exchange['last'] < 50000:
            percent = float(((starting_price - exchange['last']) * 100) / exchange['last'])
            if percent >= 1.5 and exchange['last'] >= 100:
                processed.append(str(exchange['market']['name']) +':'+ str(exchange['last']))
        if len(processed) == 0:
            sleep(30)
            continue
        else:
            break
    
processed
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-33a5acff2036> in <module>
#       8                 processed.append(str(exchange['market']['name']) +':'+ str(exchange['last']))
#       9         if len(processed) == 0:
# ---> 10             sleep(30)
#      11             continue
#      12         else:
#
# KeyboardInterrupt:
